# %%
from ultralytics import RTDETR
import ultralytics
import cv2

# %%
model_path = '../models/rtdetr-l-drone.pt'
yolo_dataset_path = "../dataset/yolo/data.yaml"

# %%
# Load a COCO-pretrained RT-DETR-l model
model = RTDETR(model_path)

# Display model information (optional)
model.info()
# Out:
# rt-detr-l summary: 460 layers, 32,808,131 parameters, 32,808,131 gradients, 108.0 GFLOPs
# (460, 32808131, 32808131, 107.991808)

# %%
results = model.train(data=yolo_dataset_path, epochs=4, imgsz=480, batch=4)

# %%
model.save(model_path)

# %%
results = model("/home/ezaborshchikov/hse_mc/hse_dl_project/dataset/yolo/images/val/img_0.jpg", show=True, show_boxes=True)
# Out:
# image 1/1 /home/ezaborshchikov/hse_mc/hse_dl_project/dataset/yolo/images/val/img_0.jpg: 640x640 1 drone, 672.6ms
# Speed: 8.7ms preprocess, 672.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
results = model("/home/ezaborshchikov/hse_mc/hse_dl_project/cvpr15/videos/drones/Video_1.avi", stream=True, show=True, show_boxes=True)

# %%
import cv2
from pprint import pprint
def is_fourcc_available(codec):
    try:
        fourcc = cv2.VideoWriter_fourcc(*codec)
        temp_video = cv2.VideoWriter('temp.mkv', fourcc, 30, (640, 480), isColor=True)
        return temp_video.isOpened()
    except:
        return False
def enumerate_fourcc_codecs():
    codecs_to_test = ["DIVX", "XVID", "MJPG", "X264", "WMV1", "WMV2", "FMP4",
                      "mp4v", "avc1", "I420", "IYUV", "mpg1", "H264"]
    available_codecs = []
    for codec in codecs_to_test:
        available_codecs.append((codec, is_fourcc_available(codec)))
    return available_codecs
if __name__ == "__main__":
    codecs = enumerate_fourcc_codecs()
    print("Available FourCC codecs:")
    pprint(codecs)
# Out:
# Available FourCC codecs:
# [('DIVX', True),
#  ('XVID', True),
#  ('MJPG', True),
#  ('X264', False),
#  ('WMV1', True),
#  ('WMV2', True),
#  ('FMP4', True),
#  ('mp4v', True),
#  ('avc1', False),
#  ('I420', True),
#  ('IYUV', True),
#  ('mpg1', True),
#  ('H264', False)]
# [ERROR:0@414.791] global cap_ffmpeg_impl.hpp:3203 open Could not find encoder for codec_id=27, error: Encoder not found
# [ERROR:0@414.791] global cap_ffmpeg_impl.hpp:3281 open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# [ WARN:0@414.795] global cap.cpp:779 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.11.0) /io/opencv/modules/videoio/src/cap_images.cpp:415: error: (-215:Assertion failed) !filename_pattern.empty() in function 'CvVideoWriter_Images'
#
#
# [ERROR:0@414.797] global cap_ffmpeg_impl.hpp:3203 open Could not find encoder for codec_id=27, error: Encoder not found
# [ERROR:0@414.797] global cap_ffmpeg_impl.hpp:3281 open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# ...

# %%
video_path = "/home/ezaborshchikov/hse_mc/hse_dl_project/cvpr15/videos/drones/Video_12.avi"
cap = cv2.VideoCapture(video_path)
video_name = 'Video_12_detections.avi'

video = cv2.VideoWriter(video_name, cv2.VideoWriter_fourcc(*'MJPG'), 10, (640, 480))

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLO11 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True, conf=0.3)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLO11 Tracking", annotated_frame)
        video.write(annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
video.release()

cv2.destroyAllWindows()
# Out:
# WARNING: not enough matching points
# 0: 640x640 1 drone, 503.9ms
# Speed: 37.7ms preprocess, 503.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 drone, 598.8ms
# Speed: 2.1ms preprocess, 598.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 562.3ms
# Speed: 9.8ms preprocess, 562.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 577.8ms
# Speed: 2.4ms preprocess, 577.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 566.4ms
# Speed: 1.9ms preprocess, 566.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 drones, 600.7ms
# Speed: 2.6ms preprocess, 600.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 drone, 504.1ms
# Speed: 1.7ms preprocess, 504.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# ...

# %%
video_path = "/home/ezaborshchikov/hse_mc/hse_dl_project/cvpr15/videos/drones/Video_1.avi"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLO11 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True, conf=0.4)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLO11 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x640 (no detections), 577.4ms
# Speed: 1.7ms preprocess, 577.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 drone, 582.1ms
# Speed: 23.1ms preprocess, 582.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 drone, 526.8ms
# Speed: 1.8ms preprocess, 526.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 532.4ms
# Speed: 1.9ms preprocess, 532.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 drone, 536.2ms
# Speed: 1.8ms preprocess, 536.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 drone, 549.3ms
# Speed: 1.6ms preprocess, 549.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 585.3ms
# Speed: 2.0ms preprocess, 585.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 drone, 500.7ms
# ...

# %%
metrics = model.val(data=yolo_dataset_path)
# Out:
# Ultralytics 8.3.78 🚀 Python-3.10.12 torch-2.6.0+cu124 CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# rt-detr-l summary: 305 layers, 31,985,795 parameters, 0 gradients, 103.4 GFLOPs
# val: Scanning /home/ezaborshchikov/hse_mc/hse_dl_project/dataset/yolo/labels/val.cache... 3076 images, 368 backgrounds, 0 corrupt: 100%|██████████| 3076/3076 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/193 [00:06<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 metrics = model.val(data=yolo_dataset_path)
#
# File ~/hse_mc/hse_dl_project/.venv/lib/python3.10/site-packages/ultralytics/engine/model.py:641, in Model.val(self, validator, **kwargs)
#     638 args = {**self.overrides, **custom, **kwargs, "mode": "val"}  # highest priority args on the right
# ...

# %%
print(metrics.box.map)  # map50-95
print(metrics.box.map50)  # map50
print(metrics.box.map75)  # map75
print(metrics.box.maps)  # a list contains map50-95 of each category
# Out:
# 0.2701403048423837
# 0.6951852024646497
# 0.11255840057226006
# [    0.27014]

# %%
results[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 results[0]
#
# TypeError: 'generator' object is not subscriptable

# %%
cv_utils.draw_yolo_annotations("/home/jacksonrr3/hse/hse_dl_project/dataset/yolo/images/val/img_0.jpg", )
